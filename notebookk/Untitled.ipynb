# %%
import pandas as pd
import googlemaps
import time

# %%
df = pd.read_csv("merchant.csv", usecols=[0, 1])
df
# Out:
#                  Merchant_Name       City
# 0                   big bazaar  new delhi
# 1             delhi metro rail  new delhi
# 2          delhi metro rail co  new delhi
# 3             lake forest wine    gurgaon
# 4                     easy day  new delhi
# 5           wine and beer shop  new delhi
# 6                     reliance  new delhi
# 7                       dsiidc  new delhi
# 8                   big bazaar    gurgaon
# 9              discovery wines    gurgaon
# 10     connaught plaza restaur  new delhi
# 11           delhi state civil  new delhi
# 12            kendriya bhandar  new delhi
# 13           delhi tourism and  new delhi
# 14        plaza premium lounge  new delhi
# 15               amazon seller  new delhi
# 16               lenskart coco    gurgaon
# 17                 burger king  new delhi
# 18                  big bazaar      noida
# 19                    haldiram    gurgaon
# 20           twenty four seven  new delhi
# 21      delhi metro rail corpo  new delhi
# 22       haldiram products pvt  new delhi
# 23                 bikanervala  new delhi
# 24             moin food court      noida
# 25         rel retail ltdfresh  new delhi
# 26               dominos pizza  new delhi
# 27            bharat petroleum  new delhi
# 28                         hcg    gurgaon
# 29                   mahalaxmi    gurgaon
# ...                        ...        ...
# 73824     payshri ram handloom  new delhi
# 73825    svam power plants pvt    gurgaon
# 73826        j k digital world  new delhi
# 73827            svana systems      noida
# 73828            j k computers  new delhi
# 73829      j k business school    gurgaon
# 73830          j n s trading c  new delhi
# 73831          j p electronics  new delhi
# 73832    paysharma automobiles    gurgaon
# 73833          shivam hospital  new delhi
# 73834          jaawi enterpris    gurgaon
# 73835           jaanvi fabrics  new delhi
# 73836   sushruta ayurvedic the  new delhi
# 73837          paysatish kumar  new delhi
# 73838   paysatnam tour and tra  new delhi
# 73839                paysaurav      noida
# 73840            j s solitaire  new delhi
# 73841           j s k garments  new delhi
# 73842              suumaya the  new delhi
# 73843        j s international  new delhi
# 73844       paysavitri medicos  new delhi
# 73845          j s electricals    gurgaon
# 73846        j s b electronics      noida
# 73847          j r g vet clini      noida
# 73848                suvastram  new delhi
# 73849     payshankar jewellers  new delhi
# 73850      j p memorial hoital  new delhi
# 73851          shivam jeweller  new delhi
# 73852         malabar gold dei  new delhi
# 73853                     none  new delhi
#
# [73854 rows x 2 columns]

# %%
search_query = df.Merchant_Name + " " + df.City
search_query
# Out:
# 0                     big bazaar new delhi
# 1               delhi metro rail new delhi
# 2            delhi metro rail co new delhi
# 3                 lake forest wine gurgaon
# 4                       easy day new delhi
# 5             wine and beer shop new delhi
# 6                       reliance new delhi
# 7                         dsiidc new delhi
# 8                       big bazaar gurgaon
# 9                  discovery wines gurgaon
# 10       connaught plaza restaur new delhi
# 11             delhi state civil new delhi
# 12              kendriya bhandar new delhi
# 13             delhi tourism and new delhi
# 14          plaza premium lounge new delhi
# 15                 amazon seller new delhi
# 16                   lenskart coco gurgaon
# 17                   burger king new delhi
# 18                        big bazaar noida
# 19                        haldiram gurgaon
# 20             twenty four seven new delhi
# 21        delhi metro rail corpo new delhi
# 22         haldiram products pvt new delhi
# 23                   bikanervala new delhi
# 24                   moin food court noida
# 25           rel retail ltdfresh new delhi
# 26                 dominos pizza new delhi
# 27              bharat petroleum new delhi
# 28                             hcg gurgaon
# 29                       mahalaxmi gurgaon
#                        ...
# 73824       payshri ram handloom new delhi
# 73825        svam power plants pvt gurgaon
# 73826          j k digital world new delhi
# 73827                  svana systems noida
# 73828              j k computers new delhi
# 73829          j k business school gurgaon
# 73830            j n s trading c new delhi
# 73831            j p electronics new delhi
# 73832        paysharma automobiles gurgaon
# 73833            shivam hospital new delhi
# 73834              jaawi enterpris gurgaon
# 73835             jaanvi fabrics new delhi
# 73836     sushruta ayurvedic the new delhi
# 73837            paysatish kumar new delhi
# 73838     paysatnam tour and tra new delhi
# 73839                      paysaurav noida
# 73840              j s solitaire new delhi
# 73841             j s k garments new delhi
# 73842                suumaya the new delhi
# 73843          j s international new delhi
# 73844         paysavitri medicos new delhi
# 73845              j s electricals gurgaon
# 73846              j s b electronics noida
# 73847                j r g vet clini noida
# 73848                  suvastram new delhi
# 73849       payshankar jewellers new delhi
# 73850        j p memorial hoital new delhi
# 73851            shivam jeweller new delhi
# 73852           malabar gold dei new delhi
# 73853                       none new delhi
# Length: 73854, dtype: object

# %%
df.shape
# Out:
# (73854, 2)

# %%
API_KEY = "AIzaSyAO6e32mq3LQaOY6T323x_AFUoSEwHn2hA"

# %%
gmaps = googlemaps.Client(key = API_KEY)

# %%
for search in search_query:
    # filename = search + ".csv"
    # f = open(filename, "w")
    
    search_result = gmaps.places(query=search)
    '''
    size_of_json = len(results)
    for i in range(size_of_json):
        row = [
            ["results"][i]["formatted_address"], 
            ["results"][i]["geometry"]["location"]["lat"], 
            ["results"][i]["geometry"]["location"]["lng"],
            ["results"][i]["name"]
        ]
        address = row[0]
        latitude = row[1]
        longitude = row[2]
        name = row[3]
    
        f.write(df.Merchant_Name + "," + df.City + "," + name + "," + address + "," + latitude + "," + longitude + "\n")
        
    f.close()
    time.sleep(2)
    '''
    # search_result = gmaps.places(page_token=search_result['next_page_token'])
